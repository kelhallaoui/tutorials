# %% [markdown]
# <h1>How to load your data as a matrix.</h1>

# %%
import nibabel as nib
import os
import matplotlib.pyplot as plt
import numpy as np

nib.Nifti1Header.quaternion_threshold = -np.finfo(np.float32).eps * 10

# %% [markdown]
# A NIFTI file contains multiple containers (I am not familiar with all of its contents yet). Among these is the data. You can directly call the .get_data() function from the nibabel library to access just the data.
#
# The data is organized as:
# height*width*slices

# %%
# The NIFTI file you wish to load. 
training_img = nib.load("1000_3.nii")
# Get the data from the NIFTI file.
training_data = training_img.get_data()

training_data.shape
# Out:
# (256, 256, 287)

# %% [markdown]
# Image the data to see the different cross-sections of the brain.

# %%
training_data[100,5,5] = 4096 

print(training_data.shape)

minim = 133
maxim = 103

plt.matshow(training_data[100,:,:]/4096, cmap='gray')
plt.plot([0,280], [maxim,maxim], c='w')
plt.plot([0,280], [minim,minim], c='w')
plt.show()

plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(training_data[:,minim,:].T/4096, cmap='gray')
plt.subplot(1,2,2)
plt.imshow(training_data[:,maxim,:].T/4096, cmap='gray')
plt.show()

plt.matshow(training_data[:,:,100].T/4096, cmap='gray')
plt.show()
# Out:
# (256, 256, 287)

# %%
np.max(training_data[:,:,:])
# Out:
# 4096
