# %% [markdown]
# # K-Means

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Generate some artificial dataset using some 2D-Gaussians.

# %%
class1 = np.random.randn(3000, 2)

class2 = np.random.randn(3000, 2)
class2[:,0] = 3+class2[:,0]
class2[:,1] = 3+class2[:,1]

class3 = np.random.randn(3000, 2)
class3[:,0] = -2+class3[:,0]
class3[:,1] = 2+class3[:,1]

class4 = np.random.randn(3000, 2)
class4[:,0] = -2+class4[:,0]
class4[:,1] = -3+class4[:,1]

data = np.append( class1, class2, axis= 0)
data = np.append( data, class3, axis= 0)
data = np.append( data, class4, axis= 0)
print(data.shape)
# Out:
# (12000, 2)

# %% [markdown]
# Plot a scatter plot of the synthetic data.

# %%
plt.scatter(data[:,0], data[:,1])
plt.show()

# %% [markdown]
# ## The K-means algorithm.
#
# Repeat until convergence <br>
# 1. Assign a label $c^i$ for each data instance corresponding with its closest centroid.
# 2. Calculate the new centroid locations as the center of all the datapoints in each label.

# %%
class Kmeans(object):
    
    def __init__(self, k=1):
        self.k = k
        
    def train(self, data):
        
        shape = data.shape
        
        ranges = np.zeros((shape[1], 2))
        centroids = np.zeros((shape[1], 2))
        
        for dim in range(shape[1]):
            ranges[dim, 0] = np.min(data[:,dim])
            ranges[dim, 1] = np.max(data[:,dim])
        print('Ranges: ')
        print(ranges)
        
        centroids = np.zeros((self.k, shape[1]))
        for i in range(self.k):
            for dim in range(shape[1]):
                centroids[i, dim] = np.random.uniform(ranges[dim, 0], ranges[dim, 1], 1)
        print('Centroids: ')
        print(centroids)
        
        plt.scatter(data[:,0], data[:,1])
        plt.scatter(centroids[:,0], centroids[:,1], c = 'r')
        plt.show()
        
        count = 0
        while count < 100:
            print('-----------------------------------------------')
            count += 1
            print('Iteration: ', count)
            
            distances = np.zeros((shape[0],self.k))
            for ix, i in enumerate(data):
                for ic, c in enumerate(centroids):
                    distances[ix, ic] = np.sqrt(np.sum((i-c)**2))
                    
            labels = np.argmin(distances, axis = 1)
            
            new_centroids = np.zeros((self.k, shape[1]))
            for centroid in range(self.k):
                temp = data[labels == centroid]
                for dim in range(shape[1]): 
                    new_centroids[centroid, dim] = np.mean(temp[:,dim])
            
            plt.scatter(data[:,0], data[:,1], c = labels)
            plt.scatter(new_centroids[:,0], new_centroids[:,1], c = 'r')
            plt.show()
            
            if np.linalg.norm(new_centroids - centroids) < np.finfo(float).eps:
                print("DONE!")
                break
                
            centroids = new_centroids
        print(centroids)
        return

# %%
kmeans = Kmeans(4)
kmeans.train(data)
# Out:
# Ranges:
# [[-6.13696047  6.55077423]
#  [-7.03826452  6.68221472]]
# Centroids:
# [[ 0.81736634  5.86328988]
#  [-4.14159774  0.41018081]
#  [ 2.99389728  0.84813725]
#  [ 6.49856954 -6.79665664]]
# -----------------------------------------------
# Iteration:  1
# -----------------------------------------------
# Iteration:  2
# -----------------------------------------------
# Iteration:  3
# -----------------------------------------------
# Iteration:  4
# -----------------------------------------------
# Iteration:  5
# -----------------------------------------------
# Iteration:  6
# -----------------------------------------------
# Iteration:  7
# -----------------------------------------------
# Iteration:  8
# -----------------------------------------------
# Iteration:  9
# -----------------------------------------------
# Iteration:  10
# -----------------------------------------------
# Iteration:  11
# -----------------------------------------------
# Iteration:  12
# -----------------------------------------------
# Iteration:  13
# -----------------------------------------------
# Iteration:  14
# -----------------------------------------------
# Iteration:  15
# DONE!
# [[ 3.02726242  2.99885486]
#  [-2.03580855  2.01863371]
#  [ 0.06212735 -0.08689671]
#  [-1.99506925 -3.00555325]]
