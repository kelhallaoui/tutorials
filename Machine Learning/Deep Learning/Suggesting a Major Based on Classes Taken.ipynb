# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv1D, MaxPooling1D, Reshape
from keras.callbacks import ModelCheckpoint
from keras.models import model_from_json
from keras import backend as K
import numpy as np
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('classes.csv')
df['Degree'] = df['Degree'].astype('category')
df["Degree_encoding"] = df["Degree"].cat.codes

X = np.asarray(df.loc[:, df.columns != 'Degree'])
Y = df['Degree_encoding']

print(X.shape)
print(Y.shape)
# Out:
# (39, 7)
# (39,)

# %%
from sklearn.model_selection import train_test_split
import keras

# Split the data
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, shuffle= True)

# The known number of output classes.
num_classes = len(set(df["Degree_encoding"]))
# Input dimensions
shape = X.shape[1::]

# We need to add a channels dimension to our data
# Channels go last for TensorFlow backend in Keras
x_train_reshaped = x_train.reshape((x_train.shape[0],) + shape)
x_test_reshaped = x_test.reshape((x_test.shape[0],) + shape)
input_shape = shape
print(input_shape)

#y_train = y_train.reshape((y_train.shape[0],1))
#y_test = y_test.reshape((y_test.shape[0],1))
# Convert class vectors to binary class matrices. This uses 1 hot encoding.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Using TensorFlow backend.
# (7,)

# %%
model = Sequential()
model.add(Dense(32,
                 activation='relu',
                 input_shape=input_shape))
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

# %%
history = epochs = 100
batch_size = 128
history = model.fit(x_train_reshaped, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test_reshaped, y_test))
# Out:
# Train on 26 samples, validate on 13 samples
# Epoch 1/100
# 26/26 [==============================] - 0s 12ms/step - loss: 0.7974 - acc: 0.5000 - val_loss: 0.7828 - val_acc: 0.5385
# Epoch 2/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.7850 - acc: 0.5000 - val_loss: 0.7707 - val_acc: 0.5385
# Epoch 3/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.7728 - acc: 0.5000 - val_loss: 0.7588 - val_acc: 0.5385
# Epoch 4/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.7609 - acc: 0.5000 - val_loss: 0.7471 - val_acc: 0.5385
# Epoch 5/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.7491 - acc: 0.5000 - val_loss: 0.7355 - val_acc: 0.5385
# Epoch 6/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.7375 - acc: 0.5000 - val_loss: 0.7239 - val_acc: 0.5385
# Epoch 7/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.7261 - acc: 0.5000 - val_loss: 0.7126 - val_acc: 0.5385
# Epoch 8/100
# 26/26 [==============================] - 0s 135us/step - loss: 0.7148 - acc: 0.5000 - val_loss: 0.7012 - val_acc: 0.5385
# Epoch 9/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.7035 - acc: 0.5000 - val_loss: 0.6898 - val_acc: 0.5385
# Epoch 10/100
# 26/26 [==============================] - 0s 135us/step - loss: 0.6923 - acc: 0.5000 - val_loss: 0.6783 - val_acc: 0.5385
# Epoch 11/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.6811 - acc: 0.5000 - val_loss: 0.6668 - val_acc: 0.5385
# Epoch 12/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.6698 - acc: 0.5000 - val_loss: 0.6552 - val_acc: 0.5385
# Epoch 13/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.6585 - acc: 0.5000 - val_loss: 0.6437 - val_acc: 0.9231
# Epoch 14/100
# 26/26 [==============================] - 0s 97us/step - loss: 0.6470 - acc: 0.8462 - val_loss: 0.6317 - val_acc: 0.9231
# Epoch 15/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.6353 - acc: 0.8846 - val_loss: 0.6199 - val_acc: 0.9231
# Epoch 16/100
# 26/26 [==============================] - 0s 96us/step - loss: 0
100
# 26/26 [==============================] - 0s 116us/step - loss: 0.2237 - acc: 1.0000 - val_loss: 0.2184 - val_acc: 1.0000
# Epoch 45/100
# 26/26 [==============================] - 0s 77us/step - loss: 0.2114 - acc: 1.0000 - val_loss: 0.2078 - val_acc: 1.0000
# Epoch 46/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.1996 - acc: 1.0000 - val_loss: 0.1977 - val_acc: 1.0000
# Epoch 47/100
# 26/26 [==============================] - 0s 135us/step - loss: 0.1884 - acc: 1.0000 - val_loss: 0.1883 - val_acc: 1.0000
# Epoch 48/100
# 26/26 [==============================] - 0s 77us/step - loss: 0.1777 - acc: 1.0000 - val_loss: 0.1797 - val_acc: 1.0000
# Epoch 49/100
# 26/26 [==============================] - 0s 135us/step - loss: 0.1677 - acc: 1.0000 - val_loss: 0.1714 - val_acc: 1.0000
# Epoch 50/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.1582 - acc: 1.0000 - val_loss: 0.1641 - val_acc: 1.0000
# Epoch 51/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.1494 - acc: 1.0000 - val_loss: 0.1570 - val_acc: 1.0000
# Epoch 52/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.1411 - acc: 1.0000 - val_loss: 0.1504 - val_acc: 1.0000
# Epoch 53/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.1333 - acc: 1.0000 - val_loss: 0.1444 - val_acc: 1.0000
# Epoch 54/100
# 26/26 [==============================] - 0s 135us/step - loss: 0.1260 - acc: 1.0000 - val_loss: 0.1388 - val_acc: 1.0000
# Epoch 55/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.1192 - acc: 1.0000 - val_loss: 0.1335 - val_acc: 1.0000
# Epoch 56/100
# 26/26 [==============================] - 0s 77us/step - loss: 0.1129 - acc: 1.0000 - val_loss: 0.1288 - val_acc: 1.0000
# Epoch 57/100
# 26/26 [==============================] - 0s 77us/step - loss: 0.1070 - acc: 1.0000 - val_loss: 0.1243 - val_acc: 1.0000
# Epoch 58/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.1014 - acc: 1.0000 - val_loss: 0.1202 - val_acc: 1.0000
# Epoch 59/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0963 - acc: 1.0000 - val_loss: 0.1164 - val_acc: 1.0000
# Epoch 60/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0915 - acc: 1.0000 - val_loss: 0.1128 - val_acc: 1.0000
# Epoch 61/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0870 - acc: 1.0000 - val_loss: 0.1095 - val_acc: 1.0000
# Epoch 62/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.0828 - acc: 1.0000 - val_loss: 0.1063 - val_acc: 1.0000
# Epoch 63/100
# 26/26 [==============================] - 0s 135us/step - loss: 0.0789 - acc: 1.0000 - val_loss: 0.1036 - val_acc: 1.0000
# Epoch 64/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.0753 - acc: 1.0000 - val_loss: 0.1009 - val_acc: 1.0000
# Epoch 65/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0718 - acc: 1.0000 - val_loss: 0.0986 - val_acc: 1.0000
# Epoch 66/100
# 26/26 [==============================] - 0s 77us/step - loss: 0.0686 - acc: 1.0000 - val_loss: 0.0964 - val_acc: 1.0000
# Epoch 67/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0656 - acc: 1.0000 - val_loss: 0.0942 - val_acc: 1.0000
# Epoch 68/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0627 - acc: 1.0000 - val_loss: 0.0920 - val_acc: 1.0000
# Epoch 69/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0600 - acc: 1.0000 - val_loss: 0.0899 - val_acc: 1.0000
# Epoch 70/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.0575 - acc: 1.0000 - val_loss: 0.0879 - val_acc: 1.0000
# Epoch 71/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0551 - acc: 1.0000 - val_loss: 0.0861 - val_acc: 1.0000
# Epoch 72/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0528 - acc: 1.0000 - val_loss: 0.0844 - val_acc: 1.0000
# Epoch 73/100
# 26/26 [==============================] - 0s 77us/step - loss: 0.0507 - acc: 1.0000 - val_loss: 0.0828 - val_acc: 1.0000
# Epoch 74/100
# 26/26 [==============================] - 0s 77us/step - loss: 0.0487 - acc: 1.0000 - val_loss: 0.0813 - val_acc: 1.0000
# Epoch 75/100
# 26/26 [==============================] - 0s 77us/step - loss: 0.0469 - acc: 1.0000 - val_loss: 0.0799 - val_acc: 1.0000
# Epoch 76/100
# 26/26 [==============================] - 0s 77us/step - loss: 0.0451 - acc: 1.0000 - val_loss: 0.0785 - val_acc: 1.0000
# Epoch 77/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.0434 - acc: 1.0000 - val_loss: 0.0771 - val_acc: 1.0000
# Epoch 78/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.0418 - acc: 1.0000 - val_loss: 0.0761 - val_acc: 1.0000
# Epoch 79/100
# 26/26 [==============================] - 0s 154us/step - loss: 0.0404 - acc: 1.0000 - val_loss: 0.0750 - val_acc: 1.0000
# Epoch 80/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0390 - acc: 1.0000 - val_loss: 0.0740 - val_acc: 1.0000
# Epoch 81/100
# 26/26 [==============================] - 0s 212us/step - loss: 0.0377 - acc: 1.0000 - val_loss: 0.0731 - val_acc: 1.0000
# Epoch 82/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0365 - acc: 1.0000 - val_loss: 0.0721 - val_acc: 1.0000
# Epoch 83/100
# 26/26 [==============================] - 0s 77us/step - loss: 0.0353 - acc: 1.0000 - val_loss: 0.0711 - val_acc: 1.0000
# Epoch 84/100
# 26/26 [==============================] - 0s 174us/step - loss: 0.0341 - acc: 1.0000 - val_loss: 0.0701 - val_acc: 1.0000
# Epoch 85/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0331 - acc: 1.0000 - val_loss: 0.0692 - val_acc: 1.0000
# Epoch 86/100
# 26/26 [==============================] - 0s 174us/step - loss: 0.0320 - acc: 1.0000 - val_loss: 0.0683 - val_acc: 1.0000
# Epoch 87/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.0310 - acc: 1.0000 - val_loss: 0.0674 - val_acc: 1.0000
# Epoch 88/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0301 - acc: 1.0000 - val_loss: 0.0665 - val_acc: 1.0000
# Epoch 89/100
# 26/26 [==============================] - 0s 135us/step - loss: 0.0292 - acc: 1.0000 - val_loss: 0.0657 - val_acc: 1.0000
# Epoch 90/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0283 - acc: 1.0000 - val_loss: 0.0650 - val_acc: 1.0000
# Epoch 91/100
# 26/26 [==============================] - 0s 77us/step - loss: 0.0275 - acc: 1.0000 - val_loss: 0.0642 - val_acc: 1.0000
# Epoch 92/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0267 - acc: 1.0000 - val_loss: 0.0635 - val_acc: 1.0000
# Epoch 93/100
# 26/26 [==============================] - 0s 174us/step - loss: 0.0260 - acc: 1.0000 - val_loss: 0.0628 - val_acc: 1.0000
# Epoch 94/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0253 - acc: 1.0000 - val_loss: 0.0621 - val_acc: 1.0000
# Epoch 95/100
# 26/26 [==============================] - 0s 135us/step - loss: 0.0246 - acc: 1.0000 - val_loss: 0.0615 - val_acc: 1.0000
# Epoch 96/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0240 - acc: 1.0000 - val_loss: 0.0608 - val_acc: 1.0000
# Epoch 97/100
# 26/26 [==============================] - 0s 116us/step - loss: 0.0233 - acc: 1.0000 - val_loss: 0.0602 - val_acc: 1.0000
# Epoch 98/100
# 26/26 [==============================] - 0s 212us/step - loss: 0.0227 - acc: 1.0000 - val_loss: 0.0595 - val_acc: 1.0000
# Epoch 99/100
# 26/26 [==============================] - 0s 135us/step - loss: 0.0222 - acc: 1.0000 - val_loss: 0.0590 - val_acc: 1.0000
# Epoch 100/100
# 26/26 [==============================] - 0s 96us/step - loss: 0.0216 - acc: 1.0000 - val_loss: 0.0584 - val_acc: 1.0000

# %%
plt.figure(figsize=(8,10))
plt.subplot(2,1,1)

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')

plt.subplot(2,1,2)
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
